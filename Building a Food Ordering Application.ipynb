# %% [markdown]
# # Building a Food Ordering Application
# Imagine you run a local restaurant and want to create an application where users can order food directly from your app. The application should display the menu options and prices to the user. The user should also be able to add and remove items to their cart and update item quantities.
#
# We will need the following global variables:
#
# * The **menu**, including menu item names and their prices.
# * The available **actions** that a user can perform while using the application.
# * The **sales tax rate** used to calculate the user's final order amount.
# * The **cart** which will hold the user's order.
#
# ## The App's building blocks
# The following functions are implemented in the module `functions.py`
# * `display_menu`: displays the menu of the day
# * `add_to_cart`: Add selected items to cart
# * `delete_from_cart`: Deletes items from the cart
# * `modify_cart`: Adds or reduces items from the cart
# * `view_cart`:  displays the cart's content
# * `checkout`: Checks out clients
# * `get_user_request`: Prompts clients for input
# * `display_actions`: Displays available actions to be taken
# * `process_user_request`: Puts everything together; implements the logic

# %%
from functions import process_user_request

# %% [markdown]
# ### Testing the Application

# %%
process_user_request()
# Out:
# Welcome to WUNA DONG CHOP
#
#
# -------------------------------
# ****   Available Options   ****
# -------------------------------
# (1) Add a new menu item to cart
# (2) Remove an item from the cart
# (3) Modify a cart item's quantity
# (4) View cart
# (5) Checkout
# (6) Exit
# Enter corresponding code to continue: 1
#
# ------------------------
# ***  Available Menu  ***
# ------------------------
# Code   Item   Unit Price
# ------------------------
# (1) Hamburger: $6.51
# (2) Cheeseburger: $7.75
# (3) Milkshake: $5.99
# (4) Fries: $2.39
# (5) Sub: $5.87
# (6) Ice Cream: $1.55
# (7) Fountain Drink: $3.45
# (8) Cookie: $3.15
# (9) Brownie: $2.46
# (10) Sauce: $0.75
#
# What do you wish to oder?
# Enter item code (Eg 1): 1
# Enter quanity (Eg 1): 5
#
# 5 Hamburger(s) added to cart...
#
#
# -------------------------------
# ****   Available Options   ****
# -------------------------------
# (1) Add a new menu item to cart
# (2) Remove an item from the cart
# ...
